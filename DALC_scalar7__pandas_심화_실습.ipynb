# %% [markdown]
# <a href="https://colab.research.google.com/github/HayunSONG9758/DALC_Scala/blob/main/DALC_scalar7__pandas_%EC%8B%AC%ED%99%94_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주관식
# 셀을 더블클릭해서  : 다음에 답을 입력하세요.

# %% [markdown]
# * matplotlib 인터페이스에는 어떤 종류가
# 있나?
# plt.figure(), x = np.linspace, plt.subplot(2,1,1), plt.plot(x, np.sin(x)),
# plt.subplot(2,1,1), plt.plot(x,np.cos(x))

# %% [markdown]
# * matlab스타일의 장점은 무엇인가

# %% [markdown]
# * 객체지향스타일의 장점은 무엇인가
# 복잡하고 상세한 설정 가능, 파이썬 프로그램 친화적

# %% [markdown]
# * 객체지향스타일은 어떨때 사용하는가
# 그림이 복잡하고 많은 설정이 필요할 때

# %% [markdown]
# # 빅데이터 시각화
# * matplotlib사용
# * 선그림과 점그림
# * 다중 서브플롯
#
# 해당 질문 밑에 있는 코드셀에 코드를 입력하세요

# %% [markdown]
# # matplotlib 인터페이스

# %% [markdown]
# ### matlab스타일 인터페이스

# %% [markdown]
# * matplotlib라이브러리 사용

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# * 그래프스타일 클래식으로 설정

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# * 두 개의 패널 중 첫 번째 패널을 생성하고 현재 축을 설정

# %%
plt.figure()
x = np.linspace(-10,10,100)

# %% [markdown]
# * 2행 1열 구조 그리드의 첫번째 패널에 사인 그래프 작성

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

# %% [markdown]
# * 2행 1열 구조 그리드의 두번째 패널에 코사인 그래프 작성

# %%
plt.subplot(2,1,1)
plt.plot(x, np.cos(x));

# %% [markdown]
# * 2행 1열의 축 객체의 배열을 형성하라

# %%
fig, ax = plt.subplots(2,1)

# %% [markdown]
# * 위의 형성한 객체에 1행에는 넘파이패키지의 sin()함수를 그려라

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(x, np.sin(x))

# %% [markdown]
# ### 기본선그림

# %% [markdown]
# ### 선그림(lineplot)
# * 위와 같은 것이 %로 시작하는 것을 jupyter notebook의 magic command라고 한다.
# * %who는 변수명의 리스트를 보여주고 %magic 은 모든 매직명령어를 보여준다.
# * 전체적인 magic 명령어에 대해서는 다음 블로그를 참고
# * http://studymake.tistory.com/601
# * matplotlib 을 jupyter notebook에서 사용할 때, plot의 이미지를 보여주기 위해 magic command를 사용하는데,
# * 이때 우리가 사용하는 inline 이외에도 다음과 같은 요소를 사용할 수 있다.
# * Available matplotlib backends: ['osx', 'qt4', 'qt5', 'gtk3', 'notebook', 'wx', 'qt', 'nbagg','gtk', 'tk', 'inline']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import pandas as pd
import numpy as np

# %% [markdown]
# *  Series를 통한 line plot 그리기

# %%
import pandas as pd

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0     1.098524
# 10    0.167289
# 20    0.771423
# 30    1.738207
# 40    0.606515
# 50   -0.473906
# 60   -1.279968
# 70   -0.949654
# 80   -2.209375
# 90   -4.341418
# dtype: float64

# %% [markdown]
# * 시리즈 s의 선그래프를 그려라

# %%
plt.plot(s)

# %% [markdown]
# *  DataFrame를 통한 line plot 그리기

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -0.380329 -0.038712 -1.179714 -0.711329
# 10 -1.557232 -0.425870 -2.471951  0.265654
# 20 -1.129888  1.102456 -1.575935 -0.507090
# 30 -2.699106  0.867012 -1.399325  0.182060
# 40 -1.295382  3.623109 -2.390900  0.410337
# 50 -2.325247  3.329197 -3.005491 -0.214379
# 60 -2.420066  3.055974 -1.779481 -0.956162
# 70 -1.672937  0.981623 -1.688109 -1.137277
# 80 -1.872981  0.017191 -1.372989 -1.468071
# 90 -3.233458  0.061275 -0.982172 -2.389090

# %% [markdown]
# * 데이터프레임 df의 선그래프를 그려라

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd262dbe910>,
#  <matplotlib.lines.Line2D at 0x7fd2631c9810>,
#  <matplotlib.lines.Line2D at 0x7fd262f40750>,
#  <matplotlib.lines.Line2D at 0x7fd262f40cd0>]

# %% [markdown]
# * 데이터프레임 df의 B열에 대해서만 선그래프를 그려라

# %%
plt.plot(df["B"])

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s2
# Out:
# a    0.310114
# b    0.895493
# c    0.221281
# d    0.701613
# e    0.132674
# f    0.006863
# g    0.435556
# h    0.398195
# i    0.247556
# j    0.668082
# k    0.197065
# l    0.167302
# m    0.675664
# n    0.440636
# o    0.591281
# p    0.222867
# dtype: float64

# %% [markdown]
# ## 막대그래프그리기

# %% [markdown]
# * s2열에 대해서 막대그래프를 그려라

# %%
s2.plot.bar()

# %% [markdown]
# s2열에 대해서 가로방향의 막대그래프를 그려라

# %%
s2.plot.barh()

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2
# Out:
# Genus         A         B         C         D
# one    0.050911  0.429325  0.697237  0.113598
# two    0.925646  0.657427  0.679143  0.673722
# three  0.747354  0.815534  0.474418  0.147574
# four   0.651915  0.183947  0.239347  0.802914
# five   0.867426  0.225381  0.903334  0.616422
# six    0.776730  0.008598  0.855852  0.141341

# %% [markdown]
# * 데이터프레임 df2의 누적막대그래프를 그려라

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# * 데이터프레임 df2의 가로방향의 누적막대그래프를 그려라

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# * s2의 히스토그램을 그려라
# (히스토그램은 인덱스가 필요없다.)

# %%
s2.plot.hist()

# %% [markdown]
# * x축의 구간개수를50개로 설정하여 s3를 히스토그램으로그려라

# %%
s2.plot.hist(bins=20)

# %% [markdown]
# ## 산점도 그리기

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)
df3 = pd.DataFrame(X, columns=["x1", "x2"])
df3
# Out:
#           x1         x2
# 0   1.436655  -3.808522
# 1  -0.725358 -10.657186
# 2   0.388589   2.320306
# 3   0.847531   0.997758
# 4   0.622224  -1.234630
# ..       ...        ...
# 95  1.512624  -0.443016
# 96 -0.796303  -0.176127
# 97  0.848095  -0.701821
# 98  0.905708  -4.133730
# 99  2.376921  -5.758780
#
# [100 rows x 2 columns]

# %% [markdown]
# * df3의 x1열을 x축으로 x2열을 y축으로 산점도를 그려라

# %%
df3.plot.scatter(x='x1', y='x2')

# %% [markdown]
# ##  플롯 조정
# * color
#
# 값 색상
#
# "b" blue
#
# "g" green
#
# "r" red
#
# "c" cyan
#
# "m" magenta
#
# "y" yellow
#
# "k" black
#
# "w" white
#
# * marker
#
# 값 마킹
#
# "." point
#
# "," pixel
#
# "o" circle
#
# "v" triangle_down
#
# "^" triangle_up
#
# "<" triangle_left
#
# ">" triangle_right
#
# "8" octagon
#
# "s" square
#
# "p" pentagon
#
# "*" star
#
# "h" hexagon
#
# "+" plus
#
# "x" x
#
# "D" diamond
#
# * line style
#
# 값 라인 스타일
#
# "-" solid line
#
# "--" dashed line
#
# "-." dash-dotted line
#
# ":" dotted line
#
# "None" draw nothing

# %% [markdown]
# * plt.plot(np.random.randn(50)에서 색상은 초록, 마킹모양은 원으로 선스타일은 dashed line으로 그려라

# %%
plt.plot(np.random.randn(50),'d--',color='g',marker='o')

# %% [markdown]
# * y=x그래프를 solid green 옵션으로 그려라

# %%
plt.plot(x,x,'-g')

# %% [markdown]
# * y=x+1그래프를 dashed cyan 옵션으로 그려라

# %%
plt.plot(x,x+1,'--c')

# %% [markdown]
# * y=x+2 그래프를 dashdot black 옵션으로 그려라

# %%
plt.plot(x,x+2,'-.k')

# %% [markdown]
# * y=x+3그래프를 dotted red 옵션으로 그려라

# %%
plt.plot(x,x+3,':r')

# %% [markdown]
# * 코사인 그래프를 그리고 x축의 범위를 (-1,11)로 y축의 범위를 (1.5,1.5)으로 설정해라

# %%
plt.plot(x, np.cos(x))
plt.xlim(-1, 11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# * 자연상수 그래프(np.exp(x)그래프를 그리고 y축의 스케일을 로그로 설정해라

# %%
plt.plot(x, np.exp(-x))

# %%
plt.plot(x, np.exp(-x))
plt.yscale("log")

# %% [markdown]
# * 사인그래프를 그리고 축의 레이블를 a sine curve로 지정하고 x축의 레이블을 x, y축의 레이블을 sin(x)라 설정해라

# %%
plt.plot(x, np.sin(x))
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# * 사인그래프를 그리고 옵션을 dash green , 레이블을 'sin(x)'로
# * 사인그래프를 그리고 옵션을 dott blue , 레이블을 'cos(x)'로
# * 두그래프의 x축의 범위를 동기화
# * 그래프의 제목을 'curves of sine and cosine'
# * x레이블을 'x'로
# * 범례표시해라

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.title('Curves of Sine and Cosine')
plt.xlabel('x')
plt.legend();
