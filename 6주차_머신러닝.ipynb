# %% [markdown]
# <a href="https://colab.research.google.com/github/HayunSONG9758/DALC_Scala/blob/main/6%EC%A3%BC%EC%B0%A8_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6주차 빅데이터 회귀분석 <p/>
# 머신러닝
# - 인공지능의 한 분야
# - 데이터 모델을 구축하는 체계적인 수단
# - **데이터를 통한 학습 모델을 도출하고 새로운 데이터에 대한 추론과 패턴 예측에 활용**
# - 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야
# - 표현(데이터 평가)과 일반화(아직 알 수 없는 데이터에 대한 처리)
# - 머신러닝의 범주
#   - **지도학습** : 데이터의 측정된 특징(자동측정 가능)과 데이터와 관련된 레이블 사이의 관계를 모델링
#   - **비지도학습** : 레이블을 참조하지 않고 데이터 세트의 특징을 모델링
# - 레이블이 연속적인 수치형 데이터일 경우 : *회귀분석*, 레이블이 범주, 클래스 등 이산적인 데이터의 경우 : *분류분석*

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.head(4)    
# 일반적으로 행을 표본이라고 하고 열을 특징이라고 함. --> 특징행렬
# 열의 마지막에는 꽃의 품종 나타내는 값 : (케바케) 이 열을 따로 구분하여 **대상(타겟)**이라고 부른다
# 대상 배열의 두드러진 특징 =  데이터로부터 예측하고자 하는 값 = 종속변수
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(42)      # numpy로 생성한 난수 데이터
x = 10*rng.rand(50)   # 0과 1사이의 난수 50개 생성하고 10을 곱하여 결과적으로 0~10 사이의 값을 갖도록
y = 2*x-1+rng.randn(50)   # y는 x에 2를 곱하고 1을 뺀 다음에 표준정규분포를 따르는 난수를 더해서 변동이 발생하도록
plt.scatter(x,y);

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)    # 절편 사용할땐 True, 안사용할땐 False

# %%
# 1차원으로 생성된 데이터 2차원으로 변경하기
X = x.reshape(50,1)
X.shape

# X = x[:, np.newaxis]
# X.shape 도 가능
# Out:
# (50, 1)

# %%
model.fit(X, y)    # 사용자가 해당 속성값을 간단히 확인 가능
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Scikit-Learn에서는 관례상 fit() 절차동안 학습된 모델모수는 뒤에 모두 _가 붙는다
print(model.coef_)    # 기울기 계수값
print(model.intercept_)   # 절편값 1개의 모수
# Out:
# [1.9776566]
# -0.9033107255311146

# %%
# 모델 정확도 확인
model.score(X, y)
# 0.97정도의 R^2(결정계수)값 산술
# 1에 가까운 값을 나타낼 수록 정확도가 높다고 판단
# Out:
# 0.9749140085676858

# %%
# 모델 추가
xfit = np.linspace(-1,11)
plt.scatter(x,y)
plt.plot(xfit, model.coef_*xfit+model.intercept_,'-r');

# %% [markdown]
# 최적의 모델 선택하기 "모델의 성과 개선방법" </p>
# 정확도가 떨어지는 모델을 개선하기 위해 초모수를 다르게 설정하는 과정이 필요할 수 있다.
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ![7.png](data:image/png;base64,...)![6.png](data:image/png;base64,...)![5.png](data:image/png;base64,...)![4.png](data:image/png;base64,...)

# %%
# 파이프라인 : 전처리 프로그램과 선형회귀 모델을 묶어놓은 프로그램
from sklearn.preprocessing import  PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

def PolynomialRegression(degree=2, **kwargs):
  return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# %%
# 데이터 생성
# 40개의 데이터를 생성하고 x와 y의 관계는 비선형
import numpy as np

def make_data(N, err=1.0, rseed=1):
  rng=np.random.RandomState(rseed)
  X=rng.rand(N)**2
  y=10-1./(X+0.1)
  if err >0:
    y += err*rng.randn(N)
    return X,y
  
X,y = make_data(40)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn;seaborn.set()

X_test=np.linspace(-0.1,1.1,500)
plt.scatter(X,y,color='black')
axis=plt.axis()

# %%
plt.scatter(X,y,color='black')

for degree in [1,2,3]:    # 반복문 내부에서 다항식의 차수를 1에서 3까지 증가시킴
  model=PolynomialRegression(degree)
  model.fit(X[:,np.newaxis],y)
  y_test=model.predict(X_test[:,np.newaxis])
  plt.plot(X_test,y_test,label=f'Degree={degree}')

  plt.axis([-0.1,1.0,-2,12])
  plt.legend(loc='best')

# %% [markdown]
# 차수를 1~10차까지 증가시킴 --> 4차식 이상으로 모델이 복잡해지면 검증점수가 미세하게 떨어짐 <- *과적합이 발생*하기에
# ==> 따라서 **최적의 모델은 3차 다항식**
# ![8.png](data:image/png;base64,...)
# ![9.png](data:image/png;base64,...)
